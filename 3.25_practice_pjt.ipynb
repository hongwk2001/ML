# %%
import numpy as np
import pandas as pd

# %%
ds={'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 'last_name': ['Miller', 'Jacobson', ".", 'Milner','Cooze'],

'age': [42, 52, 36, 24, 73], 'preTestScore': [4, 24, 31, ".", "."],'postTestScore': ["25,000", "94,000", 57, 62, 70]}

# %%
df = pd.DataFrame(data=ds)

# %%
df
# Out:
#   first_name last_name  age preTestScore postTestScore
# 0      Jason    Miller   42            4        25,000
# 1      Molly  Jacobson   52           24        94,000
# 2       Tina         .   36           31            57
# 3       Jake    Milner   24            .            62
# 4        Amy     Cooze   73            .            70

# %%
df.to_csv('project.csv')

# %%
df_nohead = pd.read_csv('project.csv', header=None)

# %%
df_nohead
# Out:
#      0           1          2    3             4              5
# 0  NaN  first_name  last_name  age  preTestScore  postTestScore
# 1  0.0       Jason     Miller   42             4         25,000
# 2  1.0       Molly   Jacobson   52            24         94,000
# 3  2.0        Tina          .   36            31             57
# 4  3.0        Jake     Milner   24             .             62
# 5  4.0         Amy      Cooze   73             .             70

# %%
df_newNames = pd.read_csv('project.csv',  names=['ID','First Name','Last Name', 'Age','Pre Test Score','Post Test Score'])

# %%
df_newNames
# Out:
#     ID  First Name  Last Name  Age Pre Test Score Post Test Score
# 0  NaN  first_name  last_name  age   preTestScore   postTestScore
# 1  0.0       Jason     Miller   42              4          25,000
# 2  1.0       Molly   Jacobson   52             24          94,000
# 3  2.0        Tina          .   36             31              57
# 4  3.0        Jake     Milner   24              .              62
# 5  4.0         Amy      Cooze   73              .              70

# %%
df_NewnamesMinus_head=pd.read_csv('project.csv', header=0,  names=['ID','First Name','Last Name', 'Age','Pre Test Score','Post Test Score'])

# %%
df_NewnamesMinus_head
# Out:
#    ID First Name Last Name  Age Pre Test Score Post Test Score
# 0   0      Jason    Miller   42              4          25,000
# 1   1      Molly  Jacobson   52             24          94,000
# 2   2       Tina         .   36             31              57
# 3   3       Jake    Milner   24              .              62
# 4   4        Amy     Cooze   73              .              70

# %%
df_2Indices=pd.read_csv('project.csv', index_col=['First Name','Last Name'], header=0,  names=['ID','First Name','Last Name', 'Age','Pre Test Score','Post Test Score'])
df_2Indices
# Out:
#                       ID  Age Pre Test Score Post Test Score
# First Name Last Name
# Jason      Miller      0   42              4          25,000
# Molly      Jacobson    1   52             24          94,000
# Tina       .           2   36             31              57
# Jake       Milner      3   24              .              62
# Amy        Cooze       4   73              .              70

# %%
pd.isna(df_2Indices)
# Out:
#                          ID    Age  Pre Test Score  Post Test Score
# First Name Last Name
# Jason      Miller     False  False           False            False
# Molly      Jacobson   False  False           False            False
# Tina       .          False  False           False            False
# Jake       Milner     False  False           False            False
# Amy        Cooze      False  False           False            False

# %%
pd.isnull(df_2Indices)
# Out:
#                          ID    Age  Pre Test Score  Post Test Score
# First Name Last Name
# Jason      Miller     False  False           False            False
# Molly      Jacobson   False  False           False            False
# Tina       .          False  False           False            False
# Jake       Milner     False  False           False            False
# Amy        Cooze      False  False           False            False

# %%
df_2Indices=pd.read_csv('project.csv', skiprows=3, header=0,  names=['ID','First Name','Last Name', 'Age','Pre Test Score','Post Test Score'])
df_2Indices
# Out:
#    ID First Name Last Name  Age Pre Test Score  Post Test Score
# 0   3       Jake    Milner   24              .               62
# 1   4        Amy     Cooze   73              .               70
