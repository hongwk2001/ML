# %%
from matplotlib import style
# %matplotlib inline
import seaborn as sns
import pandas as pd

# %%
df_auto_dataset = pd.read_csv(r"C:\Users\hongw\Downloads\1602681082_datasets\auto_data.csv",)

# %%
df_auto_dataset.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
def origin(num):
    if num == 1:
        return 'URA'
    elif num ==2:
        return 'Europe'
    else :
        return 'Asia'

# %%
df_auto_dataset['origin'] = df_auto_dataset['origin'].apply(origin)

# %%
df_auto_dataset.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#   origin                       name
# 0    URA  chevrolet chevelle malibu
# 1    URA          buick skylark 320
# 2    URA         plymouth satellite
# 3    URA              amc rebel sst
# 4    URA                ford torino

# %%
sns.pairplot(df_auto_dataset[['mpg','weight','origin']],hue='origin',size=4)
# Out:
# C:\Users\hongw\anaconda3\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
